# %%
#Ucitavanje biblioteka

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
from plotly.offline import iplot, plot

# %%
#Ucitavanje csv fajla

data = pd.read_csv('songs_normalize.csv')
data.head(10)
# Out:
#             artist                    song  duration_ms  explicit  year  \
# 0   Britney Spears  Oops!...I Did It Again       211160     False  2000
# 1        blink-182    All The Small Things       167066     False  1999
# 2       Faith Hill                 Breathe       250546     False  1999
# 3         Bon Jovi            It's My Life       224493     False  2000
# 4           *NSYNC             Bye Bye Bye       200560     False  2000
# 5            Sisqo              Thong Song       253733      True  1999
# 6           Eminem     The Real Slim Shady       284200      True  2000
# 7  Robbie Williams                 Rock DJ       258560     False  2000
# 8  Destiny's Child             Say My Name       271333     False  1999
# 9            Modjo  Lady - Hear Me Tonight       307153     False  2001
#
#    popularity  danceability  energy  key  loudness  mode  speechiness  \
# 0          77         0.751   0.834    1    -5.444     0       0.0437
# ...

# %%
print(f"Broj izvodjaca: {data['artist'].nunique()}.")
# Out:
# Broj izvodjaca: 835.

# %%
data.describe()
# Out:
#          duration_ms        year   popularity  danceability       energy  \
# count    2000.000000  2000.00000  2000.000000   2000.000000  2000.000000
# mean   228748.124500  2009.49400    59.872500      0.667438     0.720366
# std     39136.569008     5.85996    21.335577      0.140416     0.152745
# min    113000.000000  1998.00000     0.000000      0.129000     0.054900
# 25%    203580.000000  2004.00000    56.000000      0.581000     0.622000
# 50%    223279.500000  2010.00000    65.500000      0.676000     0.736000
# 75%    248133.000000  2015.00000    73.000000      0.764000     0.839000
# max    484146.000000  2020.00000    89.000000      0.975000     0.999000
#
#                key     loudness         mode  speechiness  acousticness  \
# count  2000.000000  2000.000000  2000.000000  2000.000000   2000.000000
# mean      5.378000    -5.512434     0.553500     0.103568      0.128955
# std       3.615059     1.933482     0.497254     0.096159      0.173346
# ...

# %%
#Informacije

data.info()
print(data.shape)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   artist            2000 non-null   object
#  1   song              2000 non-null   object
#  2   duration_ms       2000 non-null   int64
#  3   explicit          2000 non-null   bool
#  4   year              2000 non-null   int64
#  5   popularity        2000 non-null   int64
#  6   danceability      2000 non-null   float64
#  7   energy            2000 non-null   float64
#  8   key               2000 non-null   int64
#  9   loudness          2000 non-null   float64
#  10  mode              2000 non-null   int64
#  11  speechiness       2000 non-null   float64
#  12  acousticness      2000 non-null   float64
#  13  instrumentalness  2000 non-null   float64
#  14  liveness          2000 non-null   float64
#  15  valence           2000 non-null   float64
# ...

# %%
#Nazivi kolona

data.columns
# Out:
# Index(['artist', 'song', 'duration_ms', 'explicit', 'year', 'popularity',
#        'danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness',
#        'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo',
#        'genre'],
#       dtype='object')

# %%
#Izmjena naziva kolona, capslk

data.rename(columns={'artist':'Artist', 'song':'Song', 'duration_ms':'Duration_MS', 'explicit':'Explicit', 
                     'year':'Year','popularity':'Popularity','danceability':'Danceability',
                     'energy':'Energy', 'key':'Key', 'loudness':'Loudness', 'mode':'Mode', 
                     'speechiness':'Speechiness', 'acousticness':'Acousticness', 
                     'instrumentalness':'Instrumentalness', 'liveness':'Liveness', 
                     'valence':'Valence', 'tempo':'Tempo','genre':'Genre'},inplace=True)

# %%
#Null vrijednosti

data.isna().sum()
# Out:
# Artist              0
# Song                0
# Duration_MS         0
# Explicit            0
# Year                0
# Popularity          0
# Danceability        0
# Energy              0
# Key                 0
# Loudness            0
# Mode                0
# Speechiness         0
# Acousticness        0
# Instrumentalness    0
# Liveness            0
# Valence             0
# Tempo               0
# Genre               0
# dtype: int64

# %%
#Duplikati

data.duplicated().sum()
# Out:
# 59

# %%
#Brisanje duplikata

data.drop_duplicates(inplace=True)

# %%
#Provjera dimezija

data.shape
# Out:
# (1941, 18)

# %%
#Deskriptivna statistika

data.describe()
# Out:
#          Duration_MS         Year   Popularity  Danceability       Energy  \
# count    1941.000000  1941.000000  1941.000000   1941.000000  1941.000000
# mean   228594.973725  2009.520350    59.633179      0.667814     0.721549
# std     39249.796103     5.875532    21.501053      0.140608     0.152872
# min    113000.000000  1998.000000     0.000000      0.129000     0.054900
# 25%    203506.000000  2004.000000    56.000000      0.581000     0.624000
# 50%    223186.000000  2010.000000    65.000000      0.676000     0.739000
# 75%    247946.000000  2015.000000    73.000000      0.765000     0.840000
# max    484146.000000  2020.000000    89.000000      0.975000     0.999000
#
#                Key     Loudness         Mode  Speechiness  Acousticness  \
# count  1941.000000  1941.000000  1941.000000  1941.000000   1941.000000
# mean      5.369397    -5.514082     0.553323     0.103783      0.128173
# std       3.615270     1.938950     0.497277     0.096148      0.172584
# ...

# %%
#Pregled godina

unique_years = sorted(data['Year'].unique())
print(unique_years)
# Out:
# [1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020]

# %%
#Koliko je pjesama izvan opsega 2000-2019

years_of_interest = [1999, 1998, 2020]
filtered_data = data[data['Year'].isin(years_of_interest)]

song_year = filtered_data['Year'].value_counts().reset_index()
song_year.columns = ['Year', 'Number of songs']

song_year
# Out:
#    Year  Number of songs
# 0  1999               38
# 1  2020                3
# 2  1998                1

# %%
#Posto nas zanimaju samo godine od 2000-2019, brisemo godine izvan tog opsega

data_years_drop = data[(data['Year'] <2000) | (data['Year'] > 2019)].index
data = data.drop(data_years_drop)
print(data.Year.unique())
data.head(5)
# Out:
# [2000 2001 2011 2002 2016 2018 2004 2010 2015 2006 2008 2019 2003 2013
#  2005 2012 2007 2009 2017 2014]
#             Artist                    Song  Duration_MS  Explicit  Year  \
# 0   Britney Spears  Oops!...I Did It Again       211160     False  2000
# 3         Bon Jovi            It's My Life       224493     False  2000
# 4           *NSYNC             Bye Bye Bye       200560     False  2000
# 6           Eminem     The Real Slim Shady       284200      True  2000
# 7  Robbie Williams                 Rock DJ       258560     False  2000
#
#    Popularity  Danceability  Energy  Key  Loudness  Mode  Speechiness  \
# 0          77         0.751   0.834    1    -5.444     0       0.0437
# 3          78         0.551   0.913    0    -4.063     0       0.0466
# 4          65         0.614   0.928    8    -4.806     0       0.0516
# 6          86         0.949   0.661    5    -4.244     0       0.0572
# 7          68         0.708   0.772    7    -4.264     1       0.0322
#
# ...

# %%
#Deskriptivna statistika

data.describe()
# Out:
#          Duration_MS         Year   Popularity  Danceability       Energy  \
# count    1899.000000  1899.000000  1899.000000   1899.000000  1899.000000
# mean   228123.525540  2009.720379    59.558715      0.667637     0.721256
# std     39116.687604     5.725938    21.683909      0.140547     0.152511
# min    113000.000000  2000.000000     0.000000      0.129000     0.054900
# 25%    203273.000000  2005.000000    56.000000      0.581000     0.624500
# 50%    222920.000000  2010.000000    65.000000      0.676000     0.738000
# 75%    247086.000000  2015.000000    73.000000      0.765000     0.839000
# max    484146.000000  2019.000000    89.000000      0.975000     0.999000
#
#                Key     Loudness         Mode  Speechiness  Acousticness  \
# count  1899.000000  1899.000000  1899.000000  1899.000000   1899.000000
# mean      5.379147    -5.503538     0.553976     0.104413      0.127722
# std       3.610882     1.931067     0.497209     0.096523      0.172951
# ...

# %%
#Provjera dimenzija

data.shape
# Out:
# (1899, 18)

# %%
count_popularity_zero = data[data['Popularity'] == 0].shape[0]

print(f"Broj redova sa Popularity jednakom 0: {count_popularity_zero}")
# Out:
# Broj redova sa Popularity jednakom 0: 126

# %%
filtered_data = data[data['Popularity'] > 0]


print(f"Broj pjesama s popularnošću većom od 0: {filtered_data.shape[0]}")

#Brisanje pjesama sa popularnoscu manjom od 0
data = filtered_data.reset_index(drop=True)
# Out:
# Broj pjesama s popularnošću većom od 0: 1773

# %%
data.shape
# Out:
# (1773, 18)

# %%
#Broj pjesama po godinama

songs_per_year = data.groupby('Year').size()

songs_per_year_d = songs_per_year.reset_index(name='Number of songs')

songs_per_year_d
# Out:
#     Year  Number of songs
# 0   2000               69
# 1   2001              104
# 2   2002               86
# 3   2003               89
# 4   2004               95
# 5   2005               97
# 6   2006               87
# 7   2007               87
# 8   2008               89
# 9   2009               81
# 10  2010               97
# 11  2011               90
# 12  2012              101
# 13  2013               74
# 14  2014               87
# 15  2015               80
# 16  2016               80
# 17  2017               91
# 18  2018              103
# 19  2019               86

# %%
#Graficki prikaz pjesama po godinama

plt.figure(figsize=(7, 4))
plt.bar(songs_per_year_d['Year'], songs_per_year_d['Number of songs'], color='skyblue')

plt.title('Broj pjesama po godinama')
plt.xlabel('Godina')
plt.ylabel('Broj pjesama')
plt.xticks(songs_per_year_d['Year'].unique(), rotation=45) 
plt.grid(axis='y')
plt.show()

# %%
#Prikaz broj pjesama po gofinama-linijski grafikon

plt.figure(figsize=(7, 5))
plt.plot(songs_per_year_d['Year'], songs_per_year_d['Number of songs'], marker='o', linestyle='-', color='lightblue', linewidth=2, label='Broj pjesama')

for i in range(len(songs_per_year_d)):
    plt.text(songs_per_year_d['Year'][i], songs_per_year_d['Number of songs'][i], songs_per_year_d['Number of songs'][i], ha='center', va='bottom')

plt.title('Broj pjesama po godinama')
plt.xlabel('Godina')
plt.ylabel('Broj pjesama')
plt.xticks(songs_per_year_d['Year'], rotation=45)
#plt.legend(loc='upper left')
plt.grid(False)
plt.show()

# %%
#Koliko ima izvodjaca

print(f"Broj izvodjaca: {data['Artist'].nunique()}.")
# Out:
# Broj izvodjaca: 788.

# %%
#Deset izvodjaca sa najvise numera

artists = data.groupby('Artist').size()

artists = artists.reset_index(name='Number of songs')

top_10_artists = artists.sort_values(by='Number of songs', ascending=False).head(10)
top_10_artists
# Out:
#              Artist  Number of songs
# 595         Rihanna               23
# 222          Eminem               21
# 117   Calvin Harris               20
# 204           Drake               20
# 182    David Guetta               18
# 110  Britney Spears               17
# 680    Taylor Swift               16
# 82          Beyoncé               16
# 371      Katy Perry               15
# 367      Kanye West               15

# %%
#Izvodjaci sa jednom pjesmom VS izvodjaci sa vise pjesama


multiple_songs_artists = artists[artists['Number of songs'] > 1].shape[0]

single_song_artists = artists[artists['Number of songs'] == 1].shape[0]

labels = ['Vise od jedne pjesme', 'Samo jedna pjesma']
sizes = [multiple_songs_artists, single_song_artists]

fig = px.pie(names=labels, values=sizes, title='Odnos izvodjaca sa vise od jedne pjesme i izvodjaca sa samo jednom pjesmom')
fig.update_traces(textinfo='percent')
fig.show()

# %%
#Najpopularniji izvodjaci- suma ocjene popularnosti

top_artists = data.groupby('Artist')['Popularity'].sum()

top_artists = top_artists.sort_values(ascending=False)
top_artists_df = pd.DataFrame({
    'Artist': top_artists.index,
    'Total Popularity': top_artists.values
})

top_artists_df.index = range(1, len(top_artists_df) + 1)

top_artists_df
# Out:
#               Artist  Total Popularity
# 1            Rihanna              1662
# 2             Eminem              1519
# 3              Drake              1424
# 4      Calvin Harris              1356
# 5       David Guetta              1185
# ..               ...               ...
# 784           M.I.A.                 1
# 785  Rich Homie Quan                 1
# 786       Aloe Blacc                 1
# 787    Bingo Players                 1
# 788             Daya                 1
#
# [788 rows x 2 columns]

# %%
#Prethodna top tri izvodjaca - prosjecna popularnost numera

selected_artists = ['Rihanna', 'Drake', 'Eminem']
filtered_data = data[data['Artist'].isin(selected_artists)]

artist_grouped = filtered_data.groupby('Artist').agg({
    'Song': 'count',
    'Popularity': 'mean'
}).reset_index()

artist_grouped.columns = ['Artist', 'Number of Songs', 'Mean Popularity']

artist_grouped = artist_grouped.sort_values(by='Mean Popularity', ascending=False)
artist_grouped.reset_index(drop=True, inplace=True)
artist_grouped.index = range(1, len(artist_grouped) + 1)

artist_grouped
# Out:
#     Artist  Number of Songs  Mean Popularity
# 1   Eminem               21        72.333333
# 2  Rihanna               23        72.260870
# 3    Drake               20        71.200000

# %%
#Izvodjaci cije pjesme imaju najvecu popularnost

average_popularity_by_artist = data.groupby('Artist')['Popularity'].mean()
num_songs_by_artist = data['Artist'].value_counts()

artist_stats = pd.DataFrame({
    'Mean Popularity': average_popularity_by_artist,
    'Number of Songs': num_songs_by_artist
})

top_10_artists = artist_stats.sort_values(by='Mean Popularity', ascending=False).head(10)

top_10_artists
# Out:
#                    Mean Popularity  Number of Songs
# Artist
# Tom Odell                     88.0                1
# The Neighbourhood             87.0                2
# WILLOW                        86.0                1
# Lewis Capaldi                 84.0                1
# Gesaffelstein                 84.0                1
# Tame Impala                   83.0                1
# MKTO                          82.0                1
# Alec Benjamin                 82.0                1
# girl in red                   82.0                1
# Foster The People             82.0                1

# %%
#Deset najpopularnijih pjesama

top_10_songs = data.sort_values(by='Popularity', ascending=False).head(10)

top_10_songs[['Artist','Song','Year','Popularity']]
# Out:
#                  Artist                  Song  Year  Popularity
# 1188  The Neighbourhood       Sweater Weather  2013          89
# 1179          Tom Odell          Another Love  2013          88
# 154              Eminem            Without Me  2002          87
# 1434             WILLOW        Wait a Minute!  2015          86
# 3                Eminem   The Real Slim Shady  2000          86
# 1600      Billie Eilish  lovely (with Khalid)  2018          86
# 1772        Post Malone               Circles  2019          85
# 1110         Bruno Mars  Locked out of Heaven  2012          85
# 1510         Ed Sheeran               Perfect  2017          85
# 1352             Avicii            The Nights  2014          85

# %%
separated_genres = data['Genre'].str.split(', ')

new_data = data.loc[data.index.repeat(separated_genres.str.len())]
new_data['Genre'] = [genre for sublist in separated_genres for genre in sublist]

genre_counts = new_data['Genre'].value_counts()

genre_counts.head(10)
# Out:
# Genre
# pop                 1442
# hip hop              707
# R&B                  406
# Dance/Electronic     332
# rock                 208
# metal                 61
# latin                 56
# set()                 21
# country               17
# Folk/Acoustic         17
# Name: count, dtype: int64

# %%
#Zamjena vrijednosti 'set()' sa 'Other' 

data['Genre'] = data['Genre'].apply(lambda x: 'Other' if x == 'set()' else x)

separated_genres = data['Genre'].str.split(', ')
new_data = data.loc[data.index.repeat(separated_genres.str.len())]

new_data['Genre'] = [genre for sublist in separated_genres for genre in sublist]

genre_counts = new_data['Genre'].value_counts()

print(genre_counts.head(10))
# Out:
# Genre
# pop                 1442
# hip hop              707
# R&B                  406
# Dance/Electronic     332
# rock                 208
# metal                 61
# latin                 56
# Other                 21
# country               17
# Folk/Acoustic         17
# Name: count, dtype: int64

# %%
#Provjera ispravnosti vrijednosti u ostalim kolonama

columns_to_check = ['Danceability', 'Energy', 'Speechiness', 'Acousticness', 'Instrumentalness', 'Liveness', 'Valence']  

for column in columns_to_check:
    if data[column].between(0, 1).all():
        print(f"Kolona '{column}' je u opsegu od 0 do 1.")
    else:
        print(f"Kolona '{column}' nije u opsegu od 0 do 1.")

print('------------------')

if (data['Loudness'] <= 0).all():
    print("Kolona 'Loudness' je ispravna.")
else:
    print("Kolona 'Loudness' nije ispravna.")

print('------------------')

unique_values = data['Explicit'].unique()
if set(unique_values).issubset({True, False}):
    print("Kolona 'Explicit' sadrži samo True ili False vrijednosti.")
else:
    print(f"Kolona 'Explicit' sadrži vrijednosti osim True i False: {unique_values}")
    
print('------------------')
    
if data['Popularity'].between(0, 100).all():
    print("Kolona 'Popularity' je u opsegu od 0 do 100.")
else:
    print("Kolona 'Popularity' nije u opsegu od 0 do 100.")
    
print('------------------')
    
unique_values1 = data['Mode'].unique()
if set(unique_values).issubset({0, 1}):
    print("Kolona 'Mode' sadrži samo 0 ili 1 vrijednosti.")
else:
    print(f"Kolona 'Mode' sadrži vrijednosti osim 0 i 1: {unique_values}")

print('------------------')


if data['Key'].apply(lambda x: isinstance(x, int) and x >= -1).all():
    print("Sve vrijednosti u koloni 'Key' su cjelobrojne.")
else:
    print("Kolona 'Key' sadrži necjelobrojne vrijednosti.")
    
if np.issubdtype(data['Tempo'].dtype, np.float64):
    print("Sve vrijednosti u koloni 'Tempo' su tipa float.")
else:
    print("Kolona 'Tempo' sadrži vrijednosti koje nisu tipa float.")
# Out:
# Kolona 'Danceability' je u opsegu od 0 do 1.
# Kolona 'Energy' je u opsegu od 0 do 1.
# Kolona 'Speechiness' je u opsegu od 0 do 1.
# Kolona 'Acousticness' je u opsegu od 0 do 1.
# Kolona 'Instrumentalness' je u opsegu od 0 do 1.
# Kolona 'Liveness' je u opsegu od 0 do 1.
# Kolona 'Valence' je u opsegu od 0 do 1.
# ------------------
# Kolona 'Loudness' je ispravna.
# ------------------
# Kolona 'Explicit' sadrži samo True ili False vrijednosti.
# ------------------
# Kolona 'Popularity' je u opsegu od 0 do 100.
# ------------------
# Kolona 'Mode' sadrži samo 0 ili 1 vrijednosti.
# ------------------
# Sve vrijednosti u koloni 'Key' su cjelobrojne.
# Sve vrijednosti u koloni 'Tempo' su tipa float.

# %%
#Najpopularnije pjesme po godinama 
grouped_by_year = data.groupby('Year')

idx = grouped_by_year['Popularity'].idxmax()
most_popular_songs_by_year = data.loc[idx, ['Year', 'Popularity', 'Song', 'Artist']]
most_popular_songs_by_year.reset_index(drop=True, inplace=True)
most_popular_songs_by_year.index = range(1, len(most_popular_songs_by_year) + 1)

most_popular_songs_by_year
# Out:
#     Year  Popularity                              Song             Artist
# 1   2000          86               The Real Slim Shady             Eminem
# 2   2001          78                        The Middle    Jimmy Eat World
# 3   2002          87                        Without Me             Eminem
# 4   2003          81                        In Da Club            50 Cent
# 5   2004          81  Yeah! (feat. Lil Jon & Ludacris)              Usher
# 6   2005          82                    Feel Good Inc.           Gorillaz
# 7   2006          82                       Promiscuous      Nelly Furtado
# 8   2007          80                     The Way I Are          Timbaland
# 9   2008          82                         Heartless         Kanye West
# 10  2009          82              Empire State Of Mind              JAY-Z
# 11  2010          81              Love The Way You Lie             Eminem
# 12  2011          82                          Paradise           Coldplay
# ...

# %%
#Prosjecna popularnost 4 zanra po godinama 
relevant_genres = ['pop', 'hip hop', 'rock', 'Dance/Electronic']

data['Genre'] = data['Genre'].str.split(',')
data_exploded = data.explode('Genre')

data_exploded['Genre'] = data_exploded['Genre'].str.strip()
filtered_data = data_exploded[data_exploded['Genre'].isin(relevant_genres)]
grouped_genre = filtered_data.groupby(['Year', 'Genre'])['Popularity'].mean().reset_index()

grouped_genre
# Out:
#     Year             Genre  Popularity
# 0   2000  Dance/Electronic   53.000000
# 1   2000           hip hop   56.750000
# 2   2000               pop   58.092593
# 3   2000              rock   64.727273
# 4   2001  Dance/Electronic   62.000000
# ..   ...               ...         ...
# 75  2018              rock   76.250000
# 76  2019  Dance/Electronic   66.800000
# 77  2019           hip hop   68.777778
# 78  2019               pop   63.098361
# 79  2019              rock   32.500000
#
# [80 rows x 3 columns]

# %%
#Grafik za Prosjecna popularnost zanrova po godinama 

plt.figure(figsize=(12, 8))

for genre in relevant_genres:
    genre_data = grouped_genre[grouped_genre['Genre'] == genre]
    plt.plot(genre_data['Year'], genre_data['Popularity'], marker='o', label=genre)
    
plt.xticks(range(int(grouped_genre['Year'].min()), int(grouped_genre['Year'].max()) + 1), rotation='vertical')

plt.title('Prosječna popularnost pjesama po godinama za različite žanrove')
plt.xlabel('Godina')
plt.ylabel('Prosječna popularnost')
plt.legend(title='Zanr')
plt.grid(True)
plt.show()

# %%
data['Duration_Seconds'] = data['Duration_MS'] / 1000

data['Minutes'] = data['Duration_Seconds'] // 60
data['Seconds'] = data['Duration_Seconds'] % 60
data['Duration_Minutes'] = data['Minutes'] + (data['Seconds'] / 100)
duration_minutes = data['Duration_Minutes']
duration_minutes
# Out:
# 0       3.31160
# 1       3.44493
# 2       3.20560
# 3       4.44200
# 4       4.18560
#          ...
# 1768    3.01026
# 1769    2.58426
# 1770    3.20593
# 1771    2.51029
# 1772    3.35280
# Name: Duration_Minutes, Length: 1773, dtype: float64

# %%
#Trajanje pjesama prosjecno

def correct_minutes(duration_minutes):
    corrected_minutes = round(duration_minutes + 0.01, 2)
    if corrected_minutes - int(corrected_minutes) >= 0.6:
        corrected_minutes = int(corrected_minutes) + 1
    return corrected_minutes

duration_minutes= data['Duration_MS']/60000

sns.set_theme()
plt.figure(figsize=(12,8))
sns.histplot(duration_minutes, bins= 30, kde= True, edgecolor= 'white', linewidth= 1.2, alpha =0.6)

plt.title('Trajanje pjesama u minutama', fontsize=16)
plt.xlabel('Duzina', fontsize=14)
plt.ylabel('Gustina', fontsize=14)

mean_duration = correct_minutes(duration_minutes.mean())
plt.axvline(x=mean_duration, color='red', linestyle='--', label=f'Prosjecno trajanje ({mean_duration:.2f})')
plt.legend()
plt.show()

# %%
average_duration_per_year = data.groupby('Year')['Duration_Seconds'].mean()
average_duration_per_year_minutes = average_duration_per_year / 60

plt.figure(figsize=(12, 8))
plt.plot(average_duration_per_year.index, average_duration_per_year_minutes.values, marker='o', linestyle='-', color='blue', linewidth=2)
plt.title('Prosjecno trajanje pjesama po godinama', fontsize=16)
plt.xlabel('Godina', fontsize=14)
plt.ylabel('Prosjecno trajanje (sek)', fontsize=14)
plt.xticks(average_duration_per_year.index.astype(int))
plt.grid(True)
y_ticks = [round(value, 2) for value in average_duration_per_year_minutes.values if round(value, 2) % 0.5 == 0]
plt.yticks(y_ticks)
plt.show()

# %%
def ms_to_minsec(ms):
    sec = ms / 1000
    return f"{int(sec // 60)}:{int(sec % 60)}"

# %%
durations = data[['Duration_MS', 'Year']].groupby('Year').mean().reset_index().iloc[2:]
durations['Duration_s'] = durations['Duration_MS'] / 1000
durations['min:sec'] = durations['Duration_MS'].apply(ms_to_minsec)
durations
# Out:
#     Year    Duration_MS  Duration_s min:sec
# 2   2002  251941.627907  251.941628    4:11
# 3   2003  236359.651685  236.359652    3:56
# 4   2004  233702.726316  233.702726    3:53
# 5   2005  237510.051546  237.510052    3:57
# 6   2006  239009.896552  239.009897    3:59
# 7   2007  233167.275862  233.167276    3:53
# 8   2008  234281.449438  234.281449    3:54
# 9   2009  236142.888889  236.142889    3:56
# 10  2010  221049.206186  221.049206    3:41
# 11  2011  229783.722222  229.783722    3:49
# 12  2012  224617.277228  224.617277    3:44
# 13  2013  232842.391892  232.842392    3:52
# 14  2014  221299.770115  221.299770    3:41
# 15  2015  220469.525000  220.469525    3:40
# 16  2016  221721.850000  221.721850    3:41
# 17  2017  211845.538462  211.845538    3:31
# 18  2018  208222.582524  208.222583    3:28
# 19  2019  196365.011628  196.365012    3:16

# %%
iplot(px.line(durations,
             x='Year',
             y='Duration_s',
             title='Prosjecno trajanje pjesama po godinama',
             text='min:sec'
             ).update_xaxes(type='category').update_traces(textposition='top right'))

# %%
#Matrica korelacije

numeric_columns = ['Duration_MS', 'Popularity', 'Danceability', 'Energy', 'Key', 'Loudness', 
                   'Speechiness', 'Acousticness', 'Instrumentalness', 'Liveness', 'Valence', 'Tempo']

correlation_matrix = data[numeric_columns].corr()

plt.figure(figsize=(12, 10))
sns.heatmap(correlation_matrix, annot=True, cmap='YlOrRd', fmt=".2f", linewidths=.5)
plt.title('Matrica korelacije', fontsize=16)
plt.show()

# %%
#Grafici za audio karakteristike

sns.set(style="whitegrid")
plt.rcParams.update({'font.size': 12})

histogram_labels = ['Popularity', 'Danceability', 'Energy', 'Speechiness', 'Loudness', 
                    'Acousticness', 'Liveness', 'Instrumentalness', 'Valence', 'Tempo']
colors = sns.color_palette("husl", 10)

fig, axes = plt.subplots(5, 2, figsize=(15, 20))

for i, (label, color) in enumerate(zip(histogram_labels, colors)):
    ax = axes[i // 2, i % 2]
    sns.histplot(data=data, x=label, ax=ax, color=color, kde=True, bins=70)  
    ax.set_title(f'{label} distribucija u popularnim numerama', fontsize=14)
    ax.set_xlabel(label, fontsize=12)
    ax.set_ylabel('Frekvencija', fontsize=12)
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)

plt.tight_layout()
plt.show()

# %%
explicit_count = data['Explicit'].value_counts()
labels = ['Eksplicitno', 'Neeksplicitno']


fig = px.pie(names=labels, values=explicit_count.values, title='Eksplicitne numere')
fig.update_traces(textinfo='percent')
fig.show()
